# %% [markdown]
# Question 1]
# For Multiplication:
# Each element in the resulting (n,m) matrix is obtained by taking the dot product of a row from the (n,k) matrix and a column from the (k,m) matrix.
# So total number of multiplication is k times number of elements(n*m) that is equal to nmk .
# For Addition,
# After performing the k multiplications for each element in the resulting matrix, you need to sum these products.
# For each element, you need to perform k−1 additions. Therefore total number of additions are k-1 times n*k that is equal to nm(k-1) .
# > Add blockquote

# %%
# Question 2

import time
import numpy as np

# Define your matrices here
A = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
B = [[9, 8, 7], [6, 5, 4], [3, 2, 1]]


# List of list method
start = time.time()
AxB = [[0 for _ in range(len(B[0]))] for _ in range(len(A))]

ar = len(A)
ac = len(A[0])
br = len(B)
bc = len(B[0])

if ac == br:
    for i in range(ar):
        for j in range(bc):
            for k in range(br):
                AxB[i][j] += A[i][k] * B[k][j]
    print("Result  using list of list method:")
    for row in AxB:
        print(row)
else:
    print("Matrix Multiplication is not possible")

end = time.time()
print("Time Taken by the list of list method =", end - start)

# Numpy method
start = time.time()
P = np.array(A)
Q = np.array(B)
PxQ = np.dot(P, Q)

print("\nResult  using numpy method:")
for row in PxQ:
    print(row)

end = time.time()
print("Time Taken by the numpy method =", end - start)
# Out:
# Result  using list of list method:
# [30, 24, 18]
# [84, 69, 54]
# [138, 114, 90]
# Time Taken by the list of list method = 0.002227306365966797
#
# Result  using numpy method:
# [30 24 18]
# [84 69 54]
# [138 114  90]
# Time Taken by the numpy method = 0.0007073879241943359

# %% [markdown]
# As seen above, it is clear that numpy method takes less time than list of lists method. This is because Numpy makes use of fragmentation i.e. it divided the task into fragments and then runs all the fragments simultaneously

# %% [markdown]
# Question 3:
#
# To find median of an array usking iterative method, we need to make multiple passes and hence the time complexity by this method would be n square.
# A better method would be Quickselect Algorithm as shown below

# %%
import time
import numpy as np
import random

# Method 1: Sequential Passes
def find_median_sequential(arr):
    n = len(arr)
    for i in range((n // 2) + 1):
        max_val = max(arr)
        if i == (n // 2):
            return max_val
        arr.remove(max_val)

# Method 2: Quickselect
def quickselect(arr, k):
    if len(arr) == 1:
        return arr[0]

    pivot = random.choice(arr)
    lows = [el for el in arr if el < pivot]
    highs = [el for el in arr if el > pivot]
    pivots = [el for el in arr if el == pivot]

    if k < len(lows):
        return quickselect(lows, k)
    elif k < len(lows) + len(pivots):
        return pivots[0]
    else:
        return quickselect(highs, k - len(lows) - len(pivots))

def find_median_quickselect(arr):
    n = len(arr)
    return quickselect(arr, n // 2)


def test_methods(arr):

    arr_copy1 = arr.copy()
    arr_copy2 = arr.copy()

    start = time.time()
    median_seq = find_median_sequential(arr_copy1)
    end = time.time()
    print(f"Median by sequential method: {median_seq}, Time taken: {end - start:.6f} seconds")

    start = time.time()
    median_quick = find_median_quickselect(arr_copy2)
    end = time.time()
    print(f"Median by quickselect method: {median_quick}, Time taken: {end - start:.6f} seconds")

    start = time.time()
    median_np = np.median(arr)
    end = time.time()
    print(f"Median by numpy method: {median_np}, Time taken: {end - start:.6f} seconds")

# Example usage
arr = [random.randint(1, 10000) for _ in range(1000)]
test_methods(arr)
# Out:
# Median by sequential method: 4969, Time taken: 0.023319 seconds
# Median by quickselect method: 4970, Time taken: 0.000737 seconds
# Median by numpy method: 4969.5, Time taken: 0.013856 seconds

# %% [markdown]
# Question 4:
# The gradient with respect to x is $$ 2xy + (y^3)cos(x) $$
#
# The gradient with respect to y is $$ x^2 + (3y^2)sinx $$

# %%
# Question 6

import sympy as sp
x, y = sp.symbols('x y')
func = (x**2)*y + (y**3)*sp.sin(x)
gradx = sp.diff(func,x)
grady = sp.diff(func,y)

print("The gradient of the following function with respect to x is ",gradx)
print("The gradient of the following function with respect to y is ",grady)
# Out:
# The gradient of the following function with respect to x is  2*x*y + y**3*cos(x)
# The gradient of the following function with respect to y is  x**2 + 3*y**2*sin(x)

# %%
#Question 7

data = {
    2022: {
        'Branch 1': {
            'Roll Number': 1,
            'Name': 'N',
            'Marks': {
                'Maths': 100,
                'English': 70,
                'Physics': 100,
                'Chemistry': 100,
            }
        },
        'Branch 2': {
            'Roll Number': 2,
            'Name': 'M',
            'Marks': {
                'Maths': 100,
                'English': 100,
                'Physics': 100,
                'Chemistry': 100,
            }
        }
    },
    2023: {
        'Branch 1': {
            'Roll Number': 1,
            'Name': 'N',
            'Marks': {
                'Maths': 100,
                'English': 70,
                'Physics': 100,
                'Chemistry': 100,
            }
        },
        'Branch 2': {
            'Roll Number':2,
            'Name': 'M',
            'Marks': {
                'Maths': 100,
                'English': 100,
                'Physics': 100,
                'Chemistry': 100,
            }
        }
    },
    2024: {
        'Branch 1': {
            'Roll Number': 1,
            'Name': 'N',
            'Marks': {
                'Maths': 100,
                'English': 70,
                'Physics': 100,
                'Chemistry': 100,
            }
        },
        'Branch 2': {
            'Roll Number': 2,
            'Name': 'M',
            'Marks': {
                'Maths': 100,
                'English': 100,
                'Physics': 100,
                'Chemistry': 100,
            }
        }
    },
    2025: {
        'Branch 1': {
            'Roll Number': 1,
            'Name': 'N',
            'Marks': {
                'Maths': 100,
                'English': 70,
                'Physics': 100,
                'Chemistry': 100,
            }
        },
        'Branch 2': {
            'Roll Number': 2,
            'Name': 'M',
            'Marks': {
                'Maths': 100,
                'English': 100,
                'Physics': 100,
                'Chemistry': 100,
            }
        }
    },
}

# %%
# Question 8

class Student:
    def __init__(self, roll_number, name, marks):
        self.roll_number = roll_number
        self.name = name
        self.marks = marks

class Branch:
    def __init__(self, name):
        self.name = name
        self.students = []

class Year:
    def __init__(self, year):
        self.year = year
        self.branches = []

student_1 = Student(1, 'N', {'Maths': 100, 'English': 70})
student_2 = Student(2, 'M', {'Maths': 50, 'English': 50})
branch_1_2022 = Branch('Branch 1')
branch_1_2022.students = [student_1, student_2]
branch_2_2022 = Branch('Branch 2')
year_2022 = Year(2022)
year_2022.branches = [branch_1_2022, branch_2_2022]


student_3 = Student(1, 'N', {'Maths': 100, 'English': 70})
student_4 = Student(2, 'M', {'Maths': 50, 'English': 50})
branch_1_2023 = Branch('Branch 1')
branch_1_2023.students = [student_3, student_4]
branch_2_2023 = Branch('Branch 2')
year_2023 = Year(2023)
year_2023.branches = [branch_1_2023, branch_2_2023]


student_5 = Student(1, 'N', {'Maths': 100, 'English': 70})
student_6 = Student(2, 'M', {'Maths': 50, 'English': 50})
branch_1_2024 = Branch('Branch 1')
branch_1_2024.students = [student_5, student_6]
branch_2_2024 = Branch('Branch 2')
year_2024 = Year(2024)
year_2024.branches = [branch_1_2024, branch_2_2024]


student_7 = Student(1, 'N', {'Maths': 100, 'English': 70})
student_8 = Student(2, 'M', {'Maths': 50, 'English': 50})
branch_1_2025 = Branch('Branch 1')
branch_1_2025.students = [student_7, student_8]
branch_2_2025 = Branch('Branch 2')
year_2025 = Year(2025)
year_2025.branches = [branch_1_2025, branch_2_2025]

database = [year_2022, Year(2023), Year(2024), Year(2025)]

# %%
#Question 9.1

import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0.5,100.5,0.5)
y1 = x
plt.plot(x,y1, label = "y=x")
plt.xlabel("x")
plt.ylabel("y")

plt.legend()
plt.grid(True)
plt.show()

# %%
#Question 9.2

import matplotlib.pyplot as plt
import numpy as np

def function_2(x):
    return x**2
x = np.arange(0.5,100.5,0.5)
y2 = function_2(x)
plt.plot(x,y2, label = "y=x^2")
plt.xlabel("x")
plt.ylabel("y")

plt.legend()
plt.grid(True)
plt.show()

# %%
#Question 9.3

import matplotlib.pyplot as plt
import numpy as np

def function(x):
    return x**3/100
x = np.arange(0.5,100.5,0.5)
y2 = function(x)
plt.plot(x,y2, label = "y=x^2")
plt.xlabel("x")
plt.ylabel("y")

plt.legend()
plt.grid(True)
plt.show()

# %%
#Question 9.4

import matplotlib.pyplot as plt
import numpy as np

def function(x):
    return np.sin(x)
x = np.arange(0.5,100.5,0.5)
y2 = function(x)
plt.plot(x,y2, label = "y=x^2")
plt.xlabel("x")
plt.ylabel("y")

plt.legend()
plt.grid(True)
plt.show()

# %%
#Question 9.5

import matplotlib.pyplot as plt
import numpy as np

def function(x):
    return (np.sin(x))/x
x = np.arange(0.5,100.5,0.5)
y2 = function(x)
plt.plot(x,y2, label = "y=x^2")
plt.xlabel("x")
plt.ylabel("y")

plt.legend()
plt.grid(True)
plt.show()

# %%
#Question 9.6

import matplotlib.pyplot as plt
import numpy as np

def function(x):
    return np.log(x)
x = np.arange(0.5,100.5,0.5)
y2 = function(x)
plt.plot(x,y2, label = "y=x^2")
plt.xlabel("x")
plt.ylabel("y")

plt.legend()
plt.grid(True)
plt.show()

# %%
#Question 9.7

import matplotlib.pyplot as plt
import numpy as np

def function(x):
    return np.exp(x)
x = np.arange(0.5,100.5,0.5)
y2 = function(x)
plt.plot(x,y2, label = "y=x^2")
plt.xlabel("x")
plt.ylabel("y")

plt.legend()
plt.grid(True)
plt.show()

# %%
# Question 10

import numpy as np
import pandas as pd

np.random.seed(36)
matrix_data = np.random.uniform(1, 2, size=(20, 5))

df = pd.DataFrame(matrix_data, columns=['a', 'b', 'c', 'd', 'e'])

print("DataFrame:")
print(df)

max_std_col = df.std().idxmax()
print("Column with the highest standard deviation:", max_std_col)

min_mean_row = df.mean(axis=1).idxmin()
print("Row with the lowest mean:")
print(df.loc[min_mean_row])
# Out:
# DataFrame:
#            a         b         c         d         e
# 0   1.728507  1.601614  1.952181  1.143173  1.807359
# 1   1.363215  1.186557  1.259151  1.629762  1.032561
# 2   1.947232  1.904318  1.550130  1.197008  1.232033
# 3   1.002366  1.226056  1.375343  1.452744  1.246079
# 4   1.460127  1.210407  1.670889  1.451769  1.592685
# 5   1.327012  1.223990  1.215618  1.171685  1.022679
# 6   1.629069  1.531413  1.243392  1.524828  1.174228
# 7   1.341936  1.998178  1.232437  1.025417  1.150733
# 8   1.483185  1.353762  1.639769  1.419413  1.187010
# 9   1.351765  1.482242  1.802009  1.402824  1.437993
# 10  1.873042  1.196441  1.721717  1.680160  1.205423
# 11  1.083013  1.207304  1.868844  1.716951  1.667637
# 12  1.400279  1.077304  1.230904  1.201255  1.162120
# 13  1.947135  1.250645  1.902852  1.771073  1.146951
# 14  1.884430  1.075059  1.663762  1.632169  1.318217
# 15  1.450715  1.786880  1.869081  1.712292  1.499993
# ...

# %%
#Question 11
import numpy as np
import pandas as pd

np.random.seed(36)
data_matrix = np.random.uniform(1, 2, size=(20, 5))

df = pd.DataFrame(data_matrix, columns=['col1', 'col2', 'col3', 'col4', 'col5'])

df["sum_col"] = df[["col1", "col2", "col3", "col4", "col5"]].sum(axis=1)
df["category"] = np.where(df["sum_col"] < 8, "LT8", "GT8")

lt8_total = df[df["category"] == "LT8"].shape[0]
lt8_std_dev = df[df["category"] == "LT8"]["sum_col"].std()
gt8_std_dev = df[df["category"] == "GT8"]["sum_col"].std()

print("DataFrame:")
print(df)

lt8_rows_total = len(df[df['category'] == 'LT8'])
print("Number of rows where the value in column 'category' is 'LT8':", lt8_rows_total)

std_dev_lt8 = df.loc[df['category'] == 'LT8', 'sum_col'].std()
print("Standard deviation of column 'sum_col' for rows where 'category' is 'LT8':", std_dev_lt8)

std_dev_gt8 = df.loc[df['category'] == 'GT8', 'sum_col'].std()
print("Standard deviation of column 'sum_col' for rows where 'category' is 'GT8':", std_dev_gt8)
# Out:
# DataFrame:
#         col1      col2      col3      col4      col5   sum_col category
# 0   1.728507  1.601614  1.952181  1.143173  1.807359  8.232835      GT8
# 1   1.363215  1.186557  1.259151  1.629762  1.032561  6.471246      LT8
# 2   1.947232  1.904318  1.550130  1.197008  1.232033  7.830722      LT8
# 3   1.002366  1.226056  1.375343  1.452744  1.246079  6.302588      LT8
# 4   1.460127  1.210407  1.670889  1.451769  1.592685  7.385876      LT8
# 5   1.327012  1.223990  1.215618  1.171685  1.022679  5.960985      LT8
# 6   1.629069  1.531413  1.243392  1.524828  1.174228  7.102930      LT8
# 7   1.341936  1.998178  1.232437  1.025417  1.150733  6.748701      LT8
# 8   1.483185  1.353762  1.639769  1.419413  1.187010  7.083139      LT8
# 9   1.351765  1.482242  1.802009  1.402824  1.437993  7.476832      LT8
# 10  1.873042  1.196441  1.721717  1.680160  1.205423  7.676782      LT8
# 11  1.083013  1.207304  1.868844  1.716951  1.667637  7.543750      LT8
# ...

# %% [markdown]
# Question 12
#
# Broadcasting is a feature in Numpy that allows the user to perform various operations between arrays of different shapes and size.

# %%
#Example
import numpy as np

matrix = np.array([[1, 2, 3],
                   [4, 5, 6]])

vector = np.array([10, 20, 30])

result = matrix + vector

print("Matrix:")
print(matrix)

print("\nVector:")
print(vector)

print("\nResult of adding matrix and vector (broadcasting):")
print(result)
# Out:
# Matrix:
# [[1 2 3]
#  [4 5 6]]
#
# Vector:
# [10 20 30]
#
# Result of adding matrix and vector (broadcasting):
# [[11 22 33]
#  [14 25 36]]

# %%
#Question 13
import numpy as np
def argmin(arr):
    if not isinstance(arr, np.ndarray):
        raise ValueError("Array is not a Numpy array")
    if arr.size == 0:
        raise ValueError(" Array is an empty array")

    index = 0
    value = arr[0]
    for i in range(0,arr.size):
        if arr[i]<value:
            value = arr[i]
            index = i
    return index
a = np.array([3,2,1,5,2,8,4,3,3])
ans = argmin(a)
print("Index of the minimum element using function defined by me = ", ans)
np_result = np.argmin(a)
print("Index of the minimum element using the numpy function = ", np_result)
# Out:
# Index of the minimum element using function defined by me =  2
# Index of the minimum element using the numpy function =  2
